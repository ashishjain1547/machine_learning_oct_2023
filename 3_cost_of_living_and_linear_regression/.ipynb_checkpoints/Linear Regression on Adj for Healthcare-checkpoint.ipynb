# %%
import pandas as pd
import statistics as st

# %%
df = pd.read_csv('COLA.csv')

# %%
df
# Out:
#         Date  Days Passed  Original Expenses  Adj for renovation  \
# 0   30/01/21           30              26472               26472
# 1   28/02/21           59              14104               14104
# 2   30/03/21           89              17511               17511
# 3   30/04/21          120              68261               68261
# 4   30/05/21          150              44429               44429
# 5   30/06/21          181              25005               25005
# 6   30/07/21          211              62296               62296
# 7   30/08/21          242              42884               42884
# 8   30/09/21          273              39078               39078
# 9   30/10/21          303             103149              103149
# 10  30/11/21          334             143702              143702
# 11  30/12/21          364             123817              123817
# 12  30/01/22          395              63275               63275
# ...

# %%
slope, intercept = st.linear_regression(df['Days Passed'], df['Adj for healthcare'])

# %%
slope
# Out:
# 96.29786834089785

# %% [markdown]
# # Bar Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Date'], df['Adj for healthcare'])

# Rotating X-axis labels
plt.xticks(rotation = 90)

plt.show()
