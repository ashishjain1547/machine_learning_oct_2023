# %% [raw]
# https://en.wikipedia.org/wiki/Zero-inflated_model

# %%
import pandas as pd
import numpy as np
import math
from mpmath import gamma
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('est earnings 29 Sep 2020 - 29 Sep 2023/report.xlsx')
# Out:
# /home/ashish/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df['inflated_earning'] = df['Estimated earnings (USD)'] * 10

# %%
df
# Out:
#            Date  Estimated earnings (USD)  Page views  Page RPM (USD)  \
# 0    2020-09-29                      0.18         238            0.74
# 1    2020-09-30                      0.03         127            0.26
# 2    2020-10-01                      0.16         150            1.04
# 3    2020-10-02                      0.29         412            0.70
# 4    2020-10-03                      0.21         367            0.58
# ...         ...                       ...         ...             ...
# 1091 2023-09-25                      0.13          25            5.29
# 1092 2023-09-26                      0.02          75            0.27
# 1093 2023-09-27                      0.02          46            0.41
# 1094 2023-09-28                      0.00          29            0.14
# 1095 2023-09-29                      0.00          14            0.04
#
#       Impressions  Impression RPM (USD)  Active View Viewable  Clicks  \
# 0             514                  0.34                0.4669       3
# 1             287                  0.11                0.4618       1
# 2             341                  0.46                0.3697       3
# 3            1027                  0.28                0.4543       5
# 4            1043                  0.21                0.4287       4
# ...           ...                   ...                   ...     ...
# 1091           84                  1.58                0.5238       1
# 1092          278                  0.07                0.5458       1
# 1093          145                  0.13                0.4255       0
# 1094           87                  0.05                0.4023       0
# 1095           36                  0.02                0.2778       0
#
#       inflated_earning
# 0                  1.8
# 1                  0.3
# 2                  1.6
# 3                  2.9
# 4                  2.1
# ...                ...
# 1091               1.3
# 1092               0.2
# 1093               0.2
# 1094               0.0
# 1095               0.0
#
# [1096 rows x 9 columns]

# %% [raw]
# from mpmath import gamma
# print(float(gamma(0.0)))
#
# # ValueError: gamma function pole

# %%
lm = (1 - math.pi) * df['inflated_earning'].mean()
print("lambda: " + str(lm))
k_list = np.linspace(1, 15, num=15)


def get_poisson_probability(lm, k):
    ret = (1 - math.pi) * math.pow(lm, k) * math.pow(math.e, -lm) / float(gamma(k))
    return ret

kl = []
pl = []

kl.append(0)
pl.append(math.pi + (1 - math.pi) * math.pow(math.e, -lm))

for i in k_list:
    kl.append(round(i / 10, 2))
    pl.append(round(get_poisson_probability(lm, i), 4))

df_report = pd.DataFrame({
    'k': kl,
    'probability': pl
})

df_report
# Out:
# lambda: -3.1596307672031783
#       k  probability
# 0   0.0   -47.318388
# 1   0.1   159.434900
# 2   0.2  -503.755400
# 3   0.3   795.840600
# 4   0.4  -838.187500
# 5   0.5   662.090700
# 6   0.6  -418.392400
# 7   0.7   220.327600
# 8   0.8   -99.450600
# 9   0.9    39.278400
# 10  1.0   -13.789500
# 11  1.1     4.357000
# 12  1.2    -1.251500
# 13  1.3     0.329500
# 14  1.4    -0.080100
# 15  1.5     0.018100

# %%
plt.scatter(df_report['k'], df_report['probability'])
plt.show()

# %% [raw]
# lm = df['Estimated earnings (USD)'].mean()
# print(lm)
# k_list = np.linspace(0, 1, num=10)
#
# for k in k_list:
#     print(k)
#     print(math.pow(lm, k))
#     print(math.pow(math.e, -lm))
#     print(gamma(k))
#     print(math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k))

# %%
lm = df['Estimated earnings (USD)'].mean()
print("lambda: " + str(lm))
k_list = np.linspace(0.05, 1.5, num=30)


def get_poisson_probability(lm, k):
    ret = math.pow(lm, k) * math.pow(math.e, -lm) / float(gamma(k))
    return ret

kl = []
pl = []

kl.append(0)
pl.append(math.pow(lm, 0) * math.pow(math.e, -lm) / float(math.factorial(0)))

for i in k_list:
    kl.append(round(i, 2))
    pl.append(get_poisson_probability(lm, i))

df_report = pd.DataFrame({
    'k': kl,
    'probability': pl
})

df_report
# Out:
# lambda: 0.14753649635036475
#        k  probability
# 0   0.00     0.862831
# 1   0.05     0.040272
# 2   0.10     0.074899
# 3   0.15     0.104100
# 4   0.20     0.128178
# 5   0.25     0.147492
# 6   0.30     0.162441
# 7   0.35     0.173443
# 8   0.40     0.180923
# 9   0.45     0.185300
# 10  0.50     0.186982
# 11  0.55     0.186357
# 12  0.60     0.183787
# 13  0.65     0.179608
# 14  0.70     0.174125
# 15  0.75     0.167616
# 16  0.80     0.160327
# 17  0.85     0.152474
# 18  0.90     0.144248
# 19  0.95     0.135810
# 20  1.00     0.127299
# 21  1.05     0.118832
# 22  1.10     0.110503
# 23  1.15     0.102390
# 24  1.20     0.094555
# 25  1.25     0.087042
# 26  1.30     0.079887
# 27  1.35     0.073112
# 28  1.40     0.066732
# 29  1.45     0.060752
# 30  1.50     0.055173

# %%
plt.scatter(df_report['k'], df_report['probability'])
plt.show()
