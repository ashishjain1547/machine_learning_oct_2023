# %%
import pandas as pd
import numpy as np
import math
from mpmath import gamma

# %%
df = pd.read_excel('est earnings 29 Sep 2020 - 29 Sep 2023/report.xlsx')
# Out:
# /home/ashish/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#            Date  Estimated earnings (USD)  Page views  Page RPM (USD)  \
# 0    2020-09-29                      0.18         238            0.74
# 1    2020-09-30                      0.03         127            0.26
# 2    2020-10-01                      0.16         150            1.04
# 3    2020-10-02                      0.29         412            0.70
# 4    2020-10-03                      0.21         367            0.58
# ...         ...                       ...         ...             ...
# 1091 2023-09-25                      0.13          25            5.29
# 1092 2023-09-26                      0.02          75            0.27
# 1093 2023-09-27                      0.02          46            0.41
# 1094 2023-09-28                      0.00          29            0.14
# 1095 2023-09-29                      0.00          14            0.04
#
#       Impressions  Impression RPM (USD)  Active View Viewable  Clicks
# 0             514                  0.34                0.4669       3
# 1             287                  0.11                0.4618       1
# 2             341                  0.46                0.3697       3
# 3            1027                  0.28                0.4543       5
# 4            1043                  0.21                0.4287       4
# ...           ...                   ...                   ...     ...
# 1091           84                  1.58                0.5238       1
# 1092          278                  0.07                0.5458       1
# 1093          145                  0.13                0.4255       0
# 1094           87                  0.05                0.4023       0
# 1095           36                  0.02                0.2778       0
#
# [1096 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# x = np.random.normal(170, 10, 250)

plt.title("Histogram for Page Views")
plt.xlabel("Page Views Buckets")
plt.hist(df['Page views'], bins=50)
plt.show()

# %%
plt.title("Histogram for Earnings")
plt.xlabel("Est Earnings Buckets")
plt.hist(df['Estimated earnings (USD)'], bins = 50)
plt.show()

# %%
import math

lm = df['Page views'].mean()
print(lm)
k_list = [25, 50, 75, 100, 125, 150, 175]

def get_poisson_probability(lm, k):
    ret = math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k)
    return ret
for i in k_list:
    print(str(i) + " " + str(get_poisson_probability(lm, i)))
# Out:
# 177.1934306569343
# 25 1.1652405062589648e-46
# 50 9.664442254115404e-30
# 75 1.9267721475046397e-18
# 100 8.329690116608149e-11
# 125 6.715016091645201e-06
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_20705/3370476749.py in <module>
#       9     return ret
#      10 for i in k_list:
# ---> 11     print(str(i) + " " + str(get_poisson_probability(lm, i)))
#
# /tmp/ipykernel_20705/3370476749.py in get_poisson_probability(lm, k)
#       6
#       7 def get_poisson_probability(lm, k):
# ----> 8     ret = math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k)
#       9     return ret
#      10 for i in k_list:
#
# OverflowError: math range error

# %%
lm = df['Estimated earnings (USD)'].mean()
print(lm)
k_list = np.linspace(0, 1, num=10)

def get_poisson_probability(lm, k):
    ret = math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k)
    return ret
for i in k_list:
    print(str(i) + " " + str(get_poisson_probability(lm, i)))
# Out:
# 0.14753649635036475
# 0.0 0.8628309475661622
# /tmp/ipykernel_20705/1462055857.py:6: DeprecationWarning: Using factorial() with floats is deprecated
#   ret = math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20705/1462055857.py in <module>
#       7     return ret
#       8 for i in k_list:
# ----> 9     print(str(i) + " " + str(get_poisson_probability(lm, i)))
#
# /tmp/ipykernel_20705/1462055857.py in get_poisson_probability(lm, k)
#       4
#       5 def get_poisson_probability(lm, k):
# ----> 6     ret = math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k)
#       7     return ret
#       8 for i in k_list:
#
# ValueError: factorial() only accepts integral values

# %% [raw]
# from mpmath import gamma
# print(float(gamma(0.0)))
#
# # ValueError: gamma function pole

# %%
lm = df['Estimated earnings (USD)'].mean()
print("lambda: " + str(lm))
k_list = np.linspace(0.1, 1.5, num=15)


def get_poisson_probability(lm, k):
    ret = math.pow(lm, k) * math.pow(math.e, -lm) / float(gamma(k))
    return ret

kl = []
pl = []

for i in k_list:
    kl.append(round(i, 2))
    pl.append(get_poisson_probability(lm, i))

df_report = pd.DataFrame({
    'k': kl,
    'probability': pl
})

df_report
# Out:
# lambda: 0.14753649635036475
#       k  probability
# 0   0.1     0.074899
# 1   0.2     0.128178
# 2   0.3     0.162441
# 3   0.4     0.180923
# 4   0.5     0.186982
# 5   0.6     0.183787
# 6   0.7     0.174125
# 7   0.8     0.160327
# 8   0.9     0.144248
# 9   1.0     0.127299
# 10  1.1     0.110503
# 11  1.2     0.094555
# 12  1.3     0.079887
# 13  1.4     0.066732
# 14  1.5     0.055173

# %%
plt.scatter(df_report['k'], df_report['probability'])
plt.show()

# %% [raw]
# lm = df['Estimated earnings (USD)'].mean()
# print(lm)
# k_list = np.linspace(0, 1, num=10)
#
# for k in k_list:
#     print(k)
#     print(math.pow(lm, k))
#     print(math.pow(math.e, -lm))
#     print(gamma(k))
#     print(math.pow(lm, k) * math.pow(math.e, -lm) / math.factorial(k))

# %%
lm = df['Estimated earnings (USD)'].mean()
print("lambda: " + str(lm))
k_list = np.linspace(0.05, 1.5, num=30)


def get_poisson_probability(lm, k):
    ret = math.pow(lm, k) * math.pow(math.e, -lm) / float(gamma(k))
    return ret

kl = []
pl = []

for i in k_list:
    kl.append(round(i, 2))
    pl.append(get_poisson_probability(lm, i))

df_report = pd.DataFrame({
    'k': kl,
    'probability': pl
})

df_report
# Out:
# lambda: 0.14753649635036475
#        k  probability
# 0   0.05     0.040272
# 1   0.10     0.074899
# 2   0.15     0.104100
# 3   0.20     0.128178
# 4   0.25     0.147492
# 5   0.30     0.162441
# 6   0.35     0.173443
# 7   0.40     0.180923
# 8   0.45     0.185300
# 9   0.50     0.186982
# 10  0.55     0.186357
# 11  0.60     0.183787
# 12  0.65     0.179608
# 13  0.70     0.174125
# 14  0.75     0.167616
# 15  0.80     0.160327
# 16  0.85     0.152474
# 17  0.90     0.144248
# 18  0.95     0.135810
# 19  1.00     0.127299
# 20  1.05     0.118832
# 21  1.10     0.110503
# 22  1.15     0.102390
# 23  1.20     0.094555
# 24  1.25     0.087042
# 25  1.30     0.079887
# 26  1.35     0.073112
# 27  1.40     0.066732
# 28  1.45     0.060752
# 29  1.50     0.055173

# %%
plt.scatter(df_report['k'], df_report['probability'])
plt.show()
